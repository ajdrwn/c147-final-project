# %% [markdown]
# ### Step 1: Mount the Google Drive
#
# Remember to use GPU runtime before mounting your Google Drive. (Runtime --> Change runtime type).

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Step 2: Open the project directory
#
# Replace `Your_Dir` with your own Drive path, for example `/content/drive/MyDrive/ECE147`.

# %%
# %cd Your_Dir/emg2qwerty

# %% [markdown]
# ### Step 3: Install required packages
#
# After installing them, Colab will require you to restart the session. After restarting, rerun Steps 1 and 2 so Drive is remounted and the notebook is back in the repo root.

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ### Step 4: Start your experiments!
#
# - Remember to download and copy the dataset to this directory: `Your_Dir/emg2qwerty/data`.
# - You may now start your experiments with any scripts! Below are examples of single-user LSTM training and testing.
# - **There are two ways to track the logs:**
#   - 1. Add `--multirun` if you want Hydra launcher-managed runs with per-job outputs under `logs/...`.
#   - 2. Omit `--multirun` if you want the logs streamed directly in the notebook while debugging. Checkpoints are still written under `logs/.../checkpoints/`.

# %% [markdown]
# #### Training
#
# - The checkpoints are saved in the folder `logs`, e.g., `logs/2025-02-09/18-24-15/checkpoints/`.

# %%
# Single-user LSTM training
# Add --multirun to the command below if you want launcher-managed runs.
# !python -m emg2qwerty.train \
  model=lstm_ctc \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1

# %% [markdown]
# #### Testing:
#
# - Replace `Your_Path_to_Checkpoint` with your checkpoint path.

# %%
# Single-user LSTM testing
# Add --multirun to the command below if you want launcher-managed runs.
# !python -m emg2qwerty.train \
  model=lstm_ctc \
  user="single_user" \
  checkpoint="Your_Path_to_Checkpoint" \
  train=False trainer.accelerator=gpu \
  decoder=ctc_greedy
